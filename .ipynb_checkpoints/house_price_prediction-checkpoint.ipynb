# %% [markdown]
# **Goal:** Is to develop a machine learning approach to make predictions on the House Price which is a regression task.
#
# **Information about the House**
#
# - Id - Unique ID for each home sold
# - date - Date of the home sale
# - bedrooms - Number of bedrooms
# - bathrooms - Number of bathrooms, where 5. accounts for a room with a toilet but no shower.
# - sqft_living - Square footage of the apartment interior living space
# - sqft_lot - Square footage of the land space
# - floors - Number of floors/level (e.g ground floor, 1st floor)
# - waterfront - This indicates whether the apartment was overlooking the waterfront or not(1 = Yes waterfront; 0 = No waterfront)
# - view - An index of 0-4 (0-Bad view, 1-ok view, 2-Semi view, 3-Good view, 4-Very good view) of how good the view of the property is.
# - condition - An index of 0-5 (0-Bad condition, 1-ok condition, 2-Semi condition, 3-Good condition, 4-Very good condition) on the condition of the apartment
# - grade - An index from 1-13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, 11-13 have a high quality of construction and design
# - sqft_above - Square footage of the interior housing space that is above ground level
# - sqft_basement - Square footage of the interior housing space that is below level
# - yr_built - The year the house was initially built
# - yr_renovated - The year of the house's last renovation
# - zipcode - The zipcode area where the house is located
# - lat - Latitude of the house
# - lon - Longitude of the house
# - sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# - sqft_lot15 - The square footage of the land space for the nearest 15 neighbors
#
# **Price(Target)** - Price of each home sold

# %% [markdown]
# # Exploratory Data Analysis and Preparation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# use xgboost model
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')
# %matplotlib inline

pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (22, 10)

import warnings
warnings.simplefilter('ignore', FutureWarning)
warnings.simplefilter('ignore', UserWarning)

# %%
data_path = r'/home/daniel/Desktop/programming/pythondatascience/datascience/datascienceprojects/datasets'
dataset = 'kc_house_data.csv'
data = pd.read_csv(f"{data_path}/{dataset}", header = 0)
print(data.shape)
data.head()
# Out:
# (21613, 21)
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Converting the Datetime feature to the right format

# %%
data['date'] = pd.to_datetime(data.date)

# %% [markdown]
# # Target Exploration (Price)

# %% [markdown]
# It is crucial to understand it in detail as this is what we are trying to predict accurately.

# %%
data.groupby('price').first()
# Out:
#                    id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price
# 75000.0    3421079032 2015-02-17         1       0.00          670     43377
# 78000.0      40000362 2014-05-06         2       1.00          780     16344
# 80000.0    8658300340 2014-05-23         1       0.75          430      5050
# 81000.0    3028200080 2015-03-24         2       1.00          730      9975
# 82000.0    3883800011 2014-11-05         3       1.00          860     10426
# ...               ...        ...       ...        ...          ...       ...
# 5350000.0  8907500070 2015-04-13         5       5.00         8000     23985
# 5570000.0  2470100110 2014-08-04         5       5.75         9200     35069
# 6890000.0  9208900037 2014-09-19         6       7.75         9890     31374
# 7060000.0  9808700762 2014-06-11         5       4.50        10040     37325
# 7700000.0  6762700020 2014-10-13         6       8.00        12050     27600
#
#            floors  waterfront  view  condition  grade  sqft_above  \
# price
# 75000.0       1.0           0     0          3      3         670
# 78000.0       1.0           0     0          1      5         780
# 80000.0       1.0           0     0          2      4         430
# 81000.0       1.0           0     0          1      5         730
# 82000.0       1.0           0     0          3      6         860
# ...           ...         ...   ...        ...    ...         ...
# 5350000.0     2.0           0     4          3     12        6720
# 5570000.0     2.0           0     0          3     13        6200
# 6890000.0     2.0           0     4          3     13        8860
# 7060000.0     2.0           1     2          3     11        7680
# 7700000.0     2.5           0     3          4     13        8570
#
#            sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# price
# 75000.0                0      1966             0    98022  47.2638 -121.906
# 78000.0                0      1942             0    98168  47.4739 -122.280
# 80000.0                0      1912             0    98014  47.6499 -121.909
# 81000.0                0      1943             0    98168  47.4808 -122.315
# 82000.0                0      1954             0    98146  47.4987 -122.341
# ...                  ...       ...           ...      ...      ...      ...
# 5350000.0           1280      2009             0    98004  47.6232 -122.220
# 5570000.0           3000      2001             0    98039  47.6289 -122.233
# 6890000.0           1030      2001             0    98039  47.6305 -122.240
# 7060000.0           2360      1940          2001    98004  47.6500 -122.214
# 7700000.0           3480      1910          1987    98102  47.6298 -122.323
#
#            sqft_living15  sqft_lot15
# price
# 75000.0             1160       42882
# 78000.0             1700       10387
# 80000.0             1200        7500
# 81000.0              860        9000
# 82000.0             1140       11250
# ...                  ...         ...
# 5350000.0           4600       21750
# 5570000.0           3560       24345
# 6890000.0           4540       42730
# 7060000.0           3930       25449
# 7700000.0           3940        8800
#
# [3625 rows x 20 columns]

# %%
data.groupby('price')['price'].mean().sort_values(ascending = False)
# Out:
# price
# 7700000.0    7700000.0
# 7060000.0    7060000.0
# 6890000.0    6890000.0
# 5570000.0    5570000.0
# 5350000.0    5350000.0
#                ...
# 82000.0        82000.0
# 81000.0        81000.0
# 80000.0        80000.0
# 78000.0        78000.0
# 75000.0        75000.0
# Name: price, Length: 3625, dtype: float64

# %%
sns.distplot(data.price)
plt.show()

# %% [markdown]
# The price has a right skewed distribution and can create problems during predictions.

# %%
data['log_price'] = np.log(np.array(data.price) + 1)
sns.distplot(data.log_price)
plt.show()

# %% [markdown]
# Now, the price follows a **Guassian distribution.**

# %% [markdown]
# # Check for Outliers

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.396058     291.509045   1971.005136     84.402258
# std        1.175459    828.089843     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15  \
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000
#
#           log_price
# count  21613.000000
# mean      13.047889
# std        0.526821
# min       11.225257
# 25%       12.682155
# 50%       13.017005
# 75%       13.377007
# max       15.856731

# %% [markdown]
# # Outlier Detection and Treatment

# %% [markdown]
# ## IQR (Inter Quantile Range) for Outlier Detection

# %%
def detect_outliers(df, col, remove_outlier = True):
    
    """
    Function to detect the presence of Outliers in a column
    when remove_outler = False or to remove 
    Outliers when remove_outler = True
    
    Args:
        df (Dataframe) : dataframe of the data
        col (string) : column name of the data
    
    Returns:
        float : detected outliers
    """
    
    if remove_outlier:
        # 1st quantile is 1%
        Q1 = df[col].quantile(0.01)
        # 3rd quantile is 99%
        Q3 = df[col].quantile(0.99)
        IQR = Q3 - Q1
        upper_limit = Q3 + 1.5 * IQR
        lower_limit = Q1 - 1.5 * IQR

        return df.loc[~((df[col] < lower_limit) | (df[col] > upper_limit))]
    
    else:
        
        Q1 = df[col].quantile(0.01)
        Q3 = df[col].quantile(0.99)
        IQR = Q3 - Q1
        upper_limit = Q3 + 1.5 * IQR
        lower_limit = Q1 - 1.5 * IQR

        return df.loc[((data[col] < lower_limit) | (df[col] > upper_limit))]

# %% [markdown]
# ### Bedrooms

# %%
detect_outliers(data, 'bedrooms', remove_outlier = False)
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 15870      6000     1.0           0     0          5      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15870            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15  log_price
# 15870           1330        4700  13.369225

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.bedrooms)
plt.show()

# %% [markdown]
# ### Bathrooms

# %%
detect_outliers(data, 'bathrooms', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.bathrooms)
plt.show()

# %% [markdown]
# ### sqft_living

# %%
detect_outliers(data, 'sqft_living', remove_outlier = False)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020 2014-10-13  7700000.0         6        8.0        12050
# 12777  1225069038 2014-05-05  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 7252      27600     2.5           0     3          4     13        8570
# 12777    307752     3.0           0     4          3     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252            3480      1910          1987    98102  47.6298 -122.323
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15  log_price
# 7252            3940        8800  15.856731
# 12777           4850      217800  14.639686

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_living)
plt.show()

# %% [markdown]
# ### sqft_lot

# %%
detect_outliers(data, 'sqft_lot', remove_outlier = False)
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 1719   1020069017 2015-03-27   700000.0         4       1.00         1300
# 3949    722069232 2014-09-05   998000.0         4       3.25         3770
# 4441   3626079040 2014-07-30   790000.0         2       3.00         2560
# 4540   2522029039 2014-09-29   550000.0         3       2.00         3650
# 6691   2624089007 2015-03-20  2000000.0         2       2.50         3900
# 7077   2724079090 2015-01-05  1650000.0         4       3.25         3920
# 7294   1923039022 2014-11-20   700000.0         2       1.75         1679
# 7647   2623069031 2014-05-21   542500.0         5       3.25         3010
# 7769   2323089009 2015-01-19   855000.0         4       3.50         4030
# 9714    225079036 2015-01-07   937500.0         4       4.00         5545
# 13006   619079096 2015-04-06   750000.0         3       2.50         2350
# 13477   822039004 2014-06-13   849900.0         2       2.00         2280
# 16188   522079022 2015-03-27   700000.0         3       2.50         2530
# 17319  3326079016 2015-05-04   190000.0         2       1.00          710
# 17576  1222069089 2014-09-04   375000.0         1       1.00          800
# 17825  2220069003 2015-02-23   425000.0         3       2.75         1360
# 20452  1125079111 2015-04-15  1600000.0         4       5.50         6530
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 1719    1651359     1.0           0     3          4      6        1300
# 3949     982998     2.0           0     0          3     10        3770
# 4441     982278     1.0           0     0          3      8        2560
# 4540     843309     2.0           0     0          4      7        3650
# 6691     920423     2.0           0     0          3     12        3900
# 7077     881654     3.0           0     3          3     11        3920
# 7294     577605     2.0           0     0          3      9        1679
# 7647    1074218     1.5           0     0          5      8        2010
# 7769    1024068     2.0           0     0          3     10        4030
# 9714     871200     2.0           0     0          3     11        3605
# 13006    715690     1.5           0     0          4      9        2350
# 13477    641203     2.0           0     0          3      9        2280
# 16188    623779     1.0           0     0          4      8        2530
# 17319   1164794     1.0           0     0          2      5         710
# 17576    533610     1.5           0     0          5      5         800
# 17825    542322     1.0           0     2          4      7        1140
# 20452    871200     2.0           0     2          3     11        6530
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1719               0      1920             0    98022  47.2313 -122.023
# 3949               0      1992             0    98058  47.4140 -122.087
# 4441               0      2004             0    98014  47.6955 -121.861
# 4540               0      1991             0    98070  47.3627 -122.496
# 6691               0      2009             0    98065  47.5371 -121.756
# 7077               0      2002             0    98024  47.5385 -121.896
# 7294               0      2001             0    98070  47.4630 -122.475
# 7647            1000      1931             0    98027  47.4564 -122.004
# 7769               0      2006             0    98045  47.4619 -121.744
# 9714            1940      2003             0    98014  47.6760 -121.882
# 13006              0      1979             0    98022  47.1622 -121.971
# 13477              0      1990             0    98070  47.4125 -122.455
# 16188              0      1980             0    98038  47.4188 -121.949
# 17319              0      1915             0    98014  47.6888 -121.909
# 17576              0      1950             0    98038  47.4134 -121.986
# 17825            220      1955             0    98022  47.2069 -122.024
# 20452              0      2008             0    98014  47.6640 -121.878
#
#        sqft_living15  sqft_lot15  log_price
# 1719            2560      425581  13.458837
# 3949            2290       37141  13.813510
# 4441            1620       40946  13.579789
# 4540            1870      273992  13.217675
# 6691            2720      411962  14.508658
# 7077            2970      112384  14.316286
# 7294            1850      358934  13.458837
# 7647            2450       68825  13.203945
# 7769            1830       11700  13.658858
# 9714            3420      871200  13.750973
# 13006           1280      325393  13.527830
# 13477           2030      224334  13.652875
# 16188           2120      100623  13.458837
# 17319           1680       16730  12.154785
# 17576           1790      216057  12.834684
# 17825           1700       60548  12.959847
# 20452           1280      858132  14.285515

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_lot)
plt.show()

# %%
# Remove outlier from sqft_lot
data = detect_outliers(data, 'sqft_lot', remove_outlier = True)

# %% [markdown]
# ### floors

# %%
detect_outliers(data, 'floors', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.floors)
plt.show()

# %% [markdown]
# ### sqft_above

# %%
detect_outliers(data, 'sqft_above', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_above)
plt.show()

# %% [markdown]
# ### sqft_basement

# %%
detect_outliers(data, 'sqft_basement', remove_outlier = False)
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 8092  1924059029 2014-06-17  4670000.0         5       6.75         9640
#
#       sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 8092     13068     1.0           1     4          3     12        4820
#
#       sqft_basement  yr_built  yr_renovated  zipcode     lat    long  \
# 8092           4820      1983          2009    98040  47.557 -122.21
#
#       sqft_living15  sqft_lot15  log_price
# 8092           3270       10454   15.35667

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_basement)
plt.show()

# %% [markdown]
# ### lat

# %%
detect_outliers(data, 'lat', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.lat)
plt.show()

# %% [markdown]
# ### long

# %%
detect_outliers(data, 'long', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.long)
plt.show()

# %% [markdown]
# ### sqft_living15

# %%
detect_outliers(data, 'sqft_living15', remove_outlier = False)
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, log_price]
# Index: []

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_living15)
plt.show()

# %% [markdown]
# ### sqft_lot15

# %%
detect_outliers(data, 'sqft_lot15', remove_outlier = False)
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 3801   1550000463 2014-08-26  637000.0         4       3.50         3080
# 8664   3226079059 2014-10-19  549950.0         3       1.75         2930
# 11183  1422029117 2014-07-11  319000.0         3       1.75         1640
# 13464  3420069060 2014-11-07  790000.0         3       2.50         2640
# 15620  2225079030 2014-12-12  180000.0         2       1.00          960
# 17659   620079042 2015-03-23  370000.0         2       1.00         2360
# 19156  1020069042 2014-10-01  858000.0         4       3.50         4370
# 21431  2725079018 2014-05-09  800000.0         4       3.25         3540
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 3801     118918     2.0           0     0          3      9        3080
# 8664     266587     2.0           0     0          3      8        2440
# 11183     53400     1.0           0     0          4      7        1640
# 13464    432036     1.5           0     3          3     10        2640
# 15620     87991     1.5           0     0          3      5         960
# 17659    105850     1.0           0     2          2      6        1180
# 19156    422967     1.0           0     2          4     10        2580
# 21431    159430     2.0           0     0          3      9        3540
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3801               0      2008             0    98019  47.7721 -121.924
# 8664             490      1995             0    98014  47.6991 -121.947
# 11183              0      1966             0    98070  47.3944 -122.506
# 13464              0      1996             0    98022  47.1795 -122.036
# 15620              0      1946             0    98014  47.6300 -121.900
# 17659           1180      1947             0    98022  47.2495 -121.970
# 19156           1790      1978             0    98022  47.2332 -122.029
# 21431              0      2007             0    98014  47.6285 -121.899
#
#        sqft_living15  sqft_lot15  log_price
# 3801            1830      434728  13.364527
# 8664            2700      438213  13.217584
# 11183           1850      380279  12.672950
# 13464           1500      560617  13.579789
# 15620           1940      392040  12.100718
# 17659           2640      386812  12.821261
# 19156           3260      422967  13.662361
# 21431           1940      392040  13.592368

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data.sqft_lot15)
plt.show()

# %%
# Remove outlier from sqft_lot15
data = detect_outliers(data, 'sqft_lot15', remove_outlier = True)

# %% [markdown]
# # Check for Missing Values

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# log_price        0
# dtype: int64

# %% [markdown]
# # Feature Analysis & Extraction

# %% [markdown]
# ## Univariant Feature Analysis

# %%
print(data.nunique())
# Out:
# id               21411
# date               372
# price             3624
# bedrooms            13
# bathrooms           30
# sqft_living       1035
# sqft_lot          9760
# floors               6
# waterfront           2
# view                 5
# condition            5
# grade               12
# sqft_above         943
# sqft_basement      306
# yr_built           116
# yr_renovated        70
# zipcode             70
# lat               5027
# long               749
# sqft_living15      777
# sqft_lot15        8672
# log_price         3624
# dtype: int64

# %%
fig, ax = plt.subplots(2, 3, figsize = (28, 11))
sns.countplot(x = 'floors', data = data, ax = ax[0][0])
sns.countplot(x = 'waterfront', data = data, ax = ax[0][1])
sns.countplot(x = 'view', data = data, ax = ax[0][2])
sns.countplot(x = 'condition', data = data, ax = ax[1][0])
sns.countplot(x = 'grade', data = data, ax = ax[1][1])
sns.countplot(x = 'bedrooms', data = data, ax = ax[1][2])
plt.show()

# %%
data.waterfront.value_counts()
# Out:
# 0    21425
# 1      163
# Name: waterfront, dtype: int64

# %% [markdown]
# Observations:
# 1. Ground floors are the most across buildings.
# 2. Almost every apartment has no waterfront.
# 3. Majority of the apartments has a very bad view.
# 4. Most of the buildings are in good condition.
# 5. Most apartments has an average construction and design.
# 6. 3 bedroom flat are the most across apartments.

# %% [markdown]
# # Datetime Feature

# %%
data.date.min(), data.date.max()
# Out:
# (Timestamp('2014-05-02 00:00:00'), Timestamp('2015-05-27 00:00:00'))

# %% [markdown]
# Clearly, this dataset is for 12 months (1 year) from the year of 2014 to 2015 of the month of May. To look at trends, we need to extract the days and months of the apartments.

# %%
data['date_day_of_week'] = data.date.dt.dayofweek
data['date_day_name'] = data.date.apply(lambda x: x.day_name())
data['date_month'] = data.date.dt.month
data['date_month_name'] = data.date.apply(lambda x: x.month_name())
data['date_week_of_year'] = data.date.dt.weekofyear
data['date_year_quarter'] = data.date.dt.quarter

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  log_price  date_day_of_week date_day_name  \
# 0           1340        5650  12.309987                 0        Monday
# 1           1690        7639  13.195616                 1       Tuesday
# 2           2720        8062  12.100718                 2     Wednesday
# 3           1360        5000  13.311331                 1       Tuesday
# 4           1800        7503  13.142168                 2     Wednesday
#
#    date_month date_month_name  date_week_of_year  date_year_quarter
# 0          10         October                 42                  4
# 1          12        December                 50                  4
# 2           2        February                  9                  1
# 3          12        December                 50                  4
# 4           2        February                  8                  1

# %%
fig, ax = plt.subplots(1, 2, figsize = (29, 9))
sns.countplot(x = 'date_day_name', data = data, ax = ax[0])
sns.countplot(x = 'date_month_name', data = data, ax = ax[1])
plt.show()

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x = 'date_year_quarter', data = data)
plt.show()

# %% [markdown]
# # Bivariate relationship with the Target feature (Price)

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15  log_price  date_day_of_week date_day_name  \
# 0           1340        5650  12.309987                 0        Monday
# 1           1690        7639  13.195616                 1       Tuesday
# 2           2720        8062  12.100718                 2     Wednesday
# 3           1360        5000  13.311331                 1       Tuesday
# 4           1800        7503  13.142168                 2     Wednesday
#
#    date_month date_month_name  date_week_of_year  date_year_quarter
# 0          10         October                 42                  4
# 1          12        December                 50                  4
# 2           2        February                  9                  1
# 3          12        December                 50                  4
# 4           2        February                  8                  1

# %% [markdown]
# # Price vs Bedroom

# %%
c = sns.boxplot(y = 'price', x = 'bedrooms', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
c = sns.barplot(y = 'price', x = 'bedrooms', data = data)
c.set_ylabel('Price probability')
plt.show()

# %% [markdown]
# Observation: This shows that apartments with 8 rooms are the most expensive.
# - The relationship is not linear.

# %% [markdown]
# # Price vs Bathrooms

# %%
sns.catplot(y = 'price', x = 'bathrooms', data = data, height = 8)
plt.show()

# %% [markdown]
# There is a linear relationship between Price and bathrooms.

# %% [markdown]
# # Price vs sqft_living

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'sqft_living', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# There is a linear relationship between Price and sqft_living.

# %% [markdown]
# # Price vs sqft_lot

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'sqft_lot', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# There is no linear relationship between the price and sqft_lot.

# %% [markdown]
# # Price vs floors

# %%
c = sns.boxplot(y = 'price', x = 'floors', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
c = sns.barplot(y = 'price', x = 'floors', data = data)
c.set_ylabel('Price probability')
plt.show()

# %% [markdown]
# # Price vs waterfront

# %%
plt.figure(figsize = (11, 6))
c = sns.boxplot(y = 'price', x = 'waterfront', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
plt.figure(figsize = (11, 6))
c = sns.barplot(y = 'price', x = 'waterfront', data = data)
c.set_ylabel('Price probability')
plt.show()

# %% [markdown]
# # Price vs view

# %%
plt.figure(figsize = (11, 6))
c = sns.boxplot(y = 'price', x = 'view', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
plt.figure(figsize = (11, 6))
c = sns.barplot(y = 'price', x = 'view', data = data)
c.set_ylabel('Price probability')
plt.show()

# %% [markdown]
# The relationship between the price and views seems linear

# %% [markdown]
# # Price vs condition

# %%
plt.figure(figsize = (11, 6))
c = sns.boxplot(y = 'price', x = 'condition', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
plt.figure(figsize = (11, 6))
c = sns.barplot(y = 'price', x = 'condition', data = data)
c.set_ylabel('Price probability')
plt.show()

# %% [markdown]
# # Price vs grade

# %%
plt.figure(figsize = (11, 6))
c = sns.boxplot(y = 'price', x = 'grade', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %%
plt.figure(figsize = (11, 6))
c = sns.barplot(y = 'price', x = 'grade', data = data)
c.set_ylabel('Price probability')
plt.show()

# %%
sns.catplot(y = 'price', x = 'grade', data = data, height = 6)
plt.show()

# %% [markdown]
# There is a linear relationship between Price and Grade.

# %% [markdown]
# # Price vs sqft_above

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'sqft_above', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# The relationship is linear

# %% [markdown]
# # Price vs sqft_basement

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'sqft_basement', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# The relationship is close to linear.

# %% [markdown]
# # Price vs yr_built

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'yr_built', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# No relationship

# %% [markdown]
# # Price vs yr_renovated

# %%
sns.catplot(y = 'price', x = 'yr_renovated', data = data, height = 8)
plt.show()

# %% [markdown]
# Relationship is not linear

# %% [markdown]
# # Price vs sqft_living15

# %%
plt.figure(figsize = (12, 5))
c = sns.scatterplot(y = 'price', x = 'sqft_living15', data = data)
c.set_ylabel('Price Probability')
plt.show()

# %% [markdown]
# The relationship is linear

# %%
# sqft_lot15, date_day_of_week, date_day_name, date_month, date_month_name, date_week_of_year, date_year_quarter

# %% [markdown]
# # Price vs date_day_of_week

# %% [markdown]
# # Price vs date_day_name

# %% [markdown]
# # Price vs date_month_name

# %% [markdown]
# # Price vs date_week_of_year

# %% [markdown]
# # Price vs date_year_quarter
